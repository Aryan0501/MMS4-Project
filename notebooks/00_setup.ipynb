# %% [markdown]
# # 00 — Setup
#
# Install dependencies and confirm the environment can read MMS CDFs and import the project's `src/` modules. Run this once after cloning the repo.

# %%
# install required packages (CPU TensorFlow). Skip if already installed.
# !pip install -q tensorflow==2.9.1 numpy==1.23.2 scipy==1.9.0 cdflib==1.3.10 matplotlib requests

# %%
# make src/ importable from the notebook
import sys, os
ROOT = os.path.dirname(os.path.abspath('.')) if os.path.basename(os.getcwd())=='notebooks' else os.path.abspath('.')
SRC = os.path.join(ROOT, 'src')
if SRC not in sys.path: sys.path.insert(0, SRC)
print('repo root:', ROOT)
print('src on path:', SRC)

# %%
import tensorflow as tf, numpy as np, cdflib, matplotlib
print('tf', tf.__version__, '| numpy', np.__version__, '| cdflib', cdflib.__version__)
import data_pipeline, model, losses, baseline, features
print('all src modules imported OK')
