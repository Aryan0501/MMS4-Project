# %%
import pandas as pd
import numpy as np
import cdflib
import matplotlib.pyplot as plt

# %%
path="C://Users//ryane//Downloads//mms1_fpi_brst_l2_des-dist_20240511144633_v3.4.0.cdf"

# %%
fp_mms1_dist = 'C://Users//ryane//Downloads//mms1_fpi_brst_l2_des-dist_20240511144633_v3.4.0.cdf'
#fp_mms1_moms = 'data/mms1/fpi/brst/l2/des-moms/2024/01/01/mms1_fpi_brst_l2_des-moms_20240101131913_v3.4.0.cdf'
#fp_mms4_dist = 'data/mms4/fpi/brst/l2/des-dist/2024/01/01/mms4_fpi_brst_l2_des-dist_20240101131913_v3.4.0.cdf'

with cdflib.CDF(fp_mms1_dist) as cdf_file:
    # Get the global attributes
    global_attributes = cdf_file.globalattsget()
    print("Attributes:")
    for attr, value in global_attributes.items():
        print(f"{attr}: {value}")

    # Get the variable names using cdf_info().rVariables and zVariables
    cdf_info = cdf_file.cdf_info()
    variables = cdf_info.rVariables + cdf_info.zVariables
    print("\nVariables:")
    for var in variables:
        print(var)

    # Get the attributes of each variable
    print("\nVariable Attributes:")
    for var in variables:
        var_attrs = cdf_file.varattsget(var)
        print(f"\nAttributes for {var}:")
        for attr, value in var_attrs.items():
            print(f"{attr}: {value}")

    # Get the data of each variable
    print("\nVariable Data Sizes:")
    for var in variables:
        data = cdf_file.varget(var)
        if type(data) == np.ndarray:
            print(f"{var}: {data.shape}")
        else:
            print(f"{var}: {data}")
# Out:
# Attributes:
# Project: ['STP>Solar-Terrestrial Physics']
# Source_name: ['MMS1>MMS Satellite Number 1']
# Discipline: ['Space Physics>Magnetospheric Science']
# Data_type: ['brst_l2_des-dist']
# Descriptor: ['DES>Dual Electron Spectrometers']
# File_naming_convention: ['source_descriptor_datatype_yyyyMMddHHmmss']
# Data_version: ['3.4.0']
# PI_name: ['J. Burch, B. Giles']
# PI_affiliation: ['SwRI, GSFC']
# TEXT: ['FPI usually operates in Fast Survey Mode in the MMS Region Of Interest (ROI) for the current Mission Phase.  Data are taken at burst (30/150 ms for DES/DIS) resolution in this mode.  Data are also made available at survey (4.5 s, etc) resolution; these form a separate product from this.  Per mission design, not all burst-resolution data are downlinked.  This product contains phase-space distribution maps of those burst-resolution data selected for downlink.  In particular, the (highest possible quality at the time of release) corrected/converted "Burst SkyMap" distributions are reported with time-stamps and other annotation characterizing the state of the instrument system at the indicated time.']
# Instrument_type: ['Plasma and Solar Wind', 'Particles (space)']
# Mission_group: ['MMS']
# Logical_source: ['mms1_fpi_brst_l2_des-dist']
# Logical_file_id: ['mms1_fpi_brst_l2_des-dist_20240511144633_v3.4.0']
# Logical_source_description: ['MMS Satellite Number 1 Dual Electron Spectrometer Burst-resolution instrument distributions']
# Time_resolution: ['30 milliseconds']
# Rules_of_use: ['See FPI Version Release Notes (https://lasp.colorado.edu/mms/sdc/public/datasets/fpi/) for rules of use.']
# Generated_by: ['FPI ITF, NASA/GSFC Code 673']
# Generation_date: ['Sat Jun 15 04:45:34 2024']
# Generation_site: ['ITF']
# MODS: ['See FPI Version Release Notes (https://lasp.colorado.edu/mms/sdc/public/datasets/fpi/) for data set modification history.']
# LINK_TEXT: ['MMS home page', 'SMART package home page', 'Science Data Center', 'FPI overview']
# LINK_TITLE: ['at GSFC', 'at SWRI', 'at LASP', 'at NASA']
# HTTP_LINK: ['http://mms.gsfc.nasa.gov', 'http://mms.space.swri.edu', 'http://lasp.colorado.edu/mms/sdc', 'http://www.nasa.gov/mission_pages/mms/spacecraft/instruments.html#fpi']
# Skeleton_version: ['$Revision: 9524 $']
# Skeleton_revdate: ['$Date: 2021-03-09 13:14:05 -0500 (Tue, 09 Mar 2021) $']
# Microsecond_offset_filename: ['v09_manifest_v17209_Stepper_Table_DES.cdf']
# Correction_table_name: ['mms1_des_f1ct_v48-1518_1527_p15.txt mms1_des_f1ct_v48-1518_1527_p16.txt']
# Correction_table_rev: ['00000']
# Energy_table_name: ['energies_des_15-17.txt']
# Dead_time_correction: ['100 ns']
# Correction_table_scaling_factor: ['0.71000']
#
# Variables:
# Epoch
# Epoch_plus_var
# Epoch_minus_var
# mms1_des_errorflags_brst
# mms1_des_compressionloss_brst
# mms1_des_steptable_parity_brst
# mms1_des_startdelphi_count_brst
# mms1_des_startdelphi_angle_brst
# mms1_des_phi_brst
# mms1_des_phi_delta_brst
# mms1_des_dist_brst
# mms1_des_disterr_brst
# mms1_des_avgf1counts_brst
# mms1_des_steptimeoffsets_brst
# mms1_des_sector_despinp_brst
# mms1_des_sector_label_brst
# mms1_des_pixel_label_brst
# mms1_des_energy_label_brst
# mms1_des_theta_brst
# mms1_des_theta_delta_brst
# mms1_des_energy_brst
# mms1_des_energy_delta_brst
#
# Variable Attributes:
#
# Attributes for Epoch:
# CATDESC: Nanoseconds since J2000
# DELTA_PLUS_VAR: Epoch_plus_var
# DELTA_MINUS_VAR: Epoch_minus_var
# FIELDNAM: Time tags
# FILLVAL: -9223372036854775808
# LABLAXIS: Epoch
# MONOTON: INCREASE
# REFERENCE_POSITION: Rotating Earth Geoid
# SCALETYP: linear
# SI_CONVERSION: 1.0e-9>s
# TIME_BASE: J2000
# TIME_SCALE: Terrestrial Time
# UNITS: ns
# VALIDMIN: -315575942816000000
# VALIDMAX: 3155716868184000000
# VAR_NOTES: MMS1 FPI/DES burst data begin-time; derived from burst packet time.
# VAR_TYPE: support_data
#
# Attributes for Epoch_plus_var:
# CATDESC: MMS1 FPI/DES epoch plus var
# FIELDNAM: MMS1 FPI/DES epoch plus var
# FORMAT: F4.2
# SI_CONVERSION: 1.0>s
# UNITS: s
# VALIDMIN: 0.0
# VALIDMAX: 4.5
# VAR_TYPE: support_data
#
# Attributes for Epoch_minus_var:
# CATDESC: MMS1 FPI/DES epoch minus var
# FIELDNAM: MMS1 FPI/DES epoch minus var
# FORMAT: F4.2
# SI_CONVERSION: 1.0>s
# UNITS: s
# VALIDMIN: 0.0
# VALIDMAX: 4.5
# VAR_TYPE: support_data
#
# Attributes for mms1_des_errorflags_brst:
# CATDESC: MMS1 FPI/DES vector of data-quality indicators at burst-start time
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES quality error flag
# FILLVAL: 4294967295
# FORMAT: I10
# LABLAXIS: errFlags
# SCALETYP: linear
# SI_CONVERSION:  >
# UNITS: 32-bit error flags
# VALIDMIN: 0
# VALIDMAX: 4294967294
# VAR_NOTES: Value of zero signifies no quality errors. For non-zero values: Bit-0 = manually flagged interval, Bit-1 = overcounting/saturation effects likely present in skymap, Bit-2 = compression pipeline error
# VAR_TYPE: data
#
# Attributes for mms1_des_compressionloss_brst:
# CATDESC: MMS1 FPI/DES compression lossless/lossy indicator at survey-start time
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES compression flag
# FILLVAL: 255
# FORMAT: I1
# LABLAXIS: compressFlag
# SCALETYP: linear
# SI_CONVERSION:  >
# UNITS: 0, 1
# VALIDMIN: 0
# VALIDMAX: 1
# VAR_NOTES: FPI/DES compression loss indicator, 0=lossless, 1=lossy
# VAR_TYPE: data
#
# Attributes for mms1_des_steptable_parity_brst:
# CATDESC: MMS1 FPI/DES step table parity, this burst
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES step table parity
# FILLVAL: 255
# FORMAT: I1
# LABLAXIS: stepTbl_par
# SCALETYP: linear
# SI_CONVERSION:  >
# UNITS: 0, 1
# VALIDMIN: 0
# VALIDMAX: 1
# VAR_NOTES: FPI/DES alternates between two tables, designated "even" (0) and "odd" (1).
# VAR_TYPE: data
#
# Attributes for mms1_des_startdelphi_count_brst:
# CATDESC: MMS1 FPI/DES Del-Phi (obs spin-phase) count at burst-start time
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES start Del-Phi count
# FILLVAL: 65535
# FORMAT: I4.4
# LABLAXIS: DelPhi_cnt
# SCALETYP: linear
# SI_CONVERSION:  >
# UNITS: del-phi counts
# VALIDMIN: 0
# VALIDMAX: 5761
# VAR_NOTES: Nominally, spin-phase counts range over [0000, 5759] cnts.  Each count represents 1/16 deg of observatory spin-phase.  Zero spin-phase angle indicates obs +X-axis aligned with the sun-sensor axis.
# VAR_TYPE: data
#
# Attributes for mms1_des_startdelphi_angle_brst:
# CATDESC: MMS1 FPI/DES Del-Phi (obs spin-phase) angle at burst-start time
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES start Del-Phi angle
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABLAXIS: DelPhi_ang
# SCALETYP: linear
# SI_CONVERSION: 0.0174532925>rad
# UNITS: deg
# VALIDMIN: 0.0
# VALIDMAX: 360.0
# VAR_NOTES: Nominally, spin-phase angles range over [0, 360) deg.  Each count represents 1/16 deg of observatory spin-phase.  Zero spin-phase angle indicates obs +X-axis aligned with the sun-sensor axis.
# VAR_TYPE: data
#
# Attributes for mms1_des_phi_brst:
# CATDESC: MMS1 FPI/DES burst sky-map instrument azimuthal angles
# COORDINATE_SYSTEM: DBCS>Despun Body Coordinate System
# DELTA_PLUS_VAR: mms1_des_phi_delta_brst
# DELTA_MINUS_VAR: mms1_des_phi_delta_brst
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES phi
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.3
# LABLAXIS: phi
# REPRESENTATION_1: p
# SCALETYP: linear
# SI_CONVERSION: 0.0174532925>rad
# UNITS: deg
# VALIDMIN: 0.0
# VALIDMAX: 360.0
# VAR_NOTES: Azimuth angles in the instrument frame; i.e., azimuthal angle of the instrument's look direction
# VAR_TYPE: support_data
#
# Attributes for mms1_des_phi_delta_brst:
# CATDESC: MMS1 FPI/DES brst sky-map azimuth angle bin deltas
# COORDINATE_SYSTEM: DBCS>Despun Body Coordinate System
# FIELDNAM: MMS1 FPI/DES delta phi
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABLAXIS: delta phi
# REPRESENTATION_1: p
# SCALETYP: linear
# SI_CONVERSION: 0.0174532925>rad
# UNITS: deg
# VALIDMIN: 0.0
# VALIDMAX: 360.0
# VAR_NOTES: Azimuth angle deltas
# VAR_TYPE: support_data
#
# Attributes for mms1_des_dist_brst:
# CATDESC: MMS1 FPI/DES burst sky-map instrument distribution
# DEPEND_0: Epoch
# DEPEND_1: mms1_des_phi_brst
# DEPEND_2: mms1_des_theta_brst
# DEPEND_3: mms1_des_energy_brst
# DISPLAY_TYPE: spectrogram
# FIELDNAM: MMS1 FPI/DES brstSkyMap dist
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABL_PTR_1: mms1_des_sector_label_brst
# LABL_PTR_2: mms1_des_pixel_label_brst
# LABL_PTR_3: mms1_des_energy_label_brst
# SCALETYP: log
# SI_CONVERSION: 1e12>s^3 m^-6
# UNITS: s^3/cm^6
# VALIDMIN: 0.0
# VALIDMAX: 1.0000000150474662e+30
# VAR_NOTES: Az bin: sector ind=00 looks "after" (spin-phase) Sun, ..., sector ind=31 looks "before" Sun dir.  Head field-of-view: pixel index=00 looks to zenith, ..., pixel index=15 looks to nadir.  FPI operations nominally bin data from 64 energy filters into 32 pairwise energy bins, indexed 0-31.  Nominally, bins are indexed in increasing energy order.  See FPI docs for details.
# VAR_TYPE: data
#
# Attributes for mms1_des_disterr_brst:
# CATDESC: MMS1 FPI/DES burst sky-map instrument distribution 1-sigma error
# DEPEND_0: Epoch
# DEPEND_1: mms1_des_phi_brst
# DEPEND_2: mms1_des_theta_brst
# DEPEND_3: mms1_des_energy_brst
# DISPLAY_TYPE: spectrogram
# FIELDNAM: MMS1 FPI/DES brstSkyMap distErr
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABL_PTR_1: mms1_des_sector_label_brst
# LABL_PTR_2: mms1_des_pixel_label_brst
# LABL_PTR_3: mms1_des_energy_label_brst
# SCALETYP: log
# SI_CONVERSION: 1e12>s^3 m^-6
# UNITS: s^3/cm^6
# VALIDMIN: 0.0
# VALIDMAX: 1.0000000150474662e+30
# VAR_NOTES: Az bin: sector ind=00 looks "after" (spin-phase) Sun, ..., sector ind=31 looks "before" Sun dir.  Head field-of-view: pixel index=00 looks to zenith, ..., pixel index=15 looks to nadir.  FPI operations nominally bin data from 64 energy filters into 32 pairwise energy bins, indexed 0-31.  Nominally, bins are indexed in increasing energy order.  See FPI docs for details.
# VAR_TYPE: data
#
# Attributes for mms1_des_avgf1counts_brst:
# CATDESC: MMS1 FPI/DES burst average f1 count values
# DEPEND_0: Epoch
# DEPEND_1: mms1_des_energy_brst
# FIELDNAM: MMS1 FPI/DES avg1cnt
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABLAXIS: avg 1-count level
# SCALETYP: linear
# SI_CONVERSION: 1e12>s^3 m^-6
# UNITS: s^3/cm^6
# VALIDMIN: 0.0
# VALIDMAX: 1.0000000150474662e+30
# VAR_NOTES: Average f1-count level as a function of energy
# VAR_TYPE: data
#
# Attributes for mms1_des_steptimeoffsets_brst:
# CATDESC: MMS1 FPI/DES burst sky-map microsecond offsets from Epoch
# DEPEND_0: Epoch
# DEPEND_1: mms1_des_phi_brst
# DEPEND_2: mms1_des_theta_brst
# DEPEND_3: mms1_des_energy_brst
# DISPLAY_TYPE: spectrogram
# FIELDNAM: MMS1 FPI/DES microsecond offsets
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABL_PTR_1: mms1_des_sector_label_brst
# LABL_PTR_2: mms1_des_pixel_label_brst
# LABL_PTR_3: mms1_des_energy_label_brst
# SCALETYP: linear
# SI_CONVERSION: 1.0e-6>s
# UNITS: us
# VALIDMIN: 0.0
# VALIDMAX: 30000000.0
# VAR_NOTES: Az bin: sector ind=00 looks "after" (spin-phase) Sun, ..., sector ind=31 looks "before" Sun dir.  Head field-of-view: pixel index=00 looks to zenith, ..., pixel index=15 looks to nadir.  FPI operations nominally bin data from 64 energy filters into 32 pairwise energy bins, indexed 0-31.  Nominally, bins are indexed in increasing energy order. Offsets reflect 128 steps over the 30 msec sweep period. See FPI docs for details.
# VAR_TYPE: data
#
# Attributes for mms1_des_sector_despinp_brst:
# CATDESC: MMS1 FPI/DES sector de-Spin P value, this burst
# DEPEND_0: Epoch
# DISPLAY_TYPE: time_series
# FIELDNAM: MMS1 FPI/DES sector de-Spin P
# FILLVAL: 255
# FORMAT: I2.2
# LABLAXIS: deSpin_P
# SCALETYP: linear
# SI_CONVERSION:  >
# UNITS: 00-32
# VALIDMIN: 0
# VALIDMAX: 32
# VAR_NOTES: Records P-value used to de-spin this burst sky-map on board.  See FPI docs for details.
# VAR_TYPE: data
#
# Attributes for mms1_des_sector_label_brst:
# CATDESC: MMS/FPI azimuth sector label used in some types of outputs
# FIELDNAM: MMS/FPI sector label
# FORMAT: A11
# LABLAXIS: mms1_des_sector_label_brst
# VAR_NOTES: Azimuth bin: "sector00" looks after Sun, ..., "sector31" looks before Sun dir.
# VAR_TYPE: metadata
#
# Attributes for mms1_des_pixel_label_brst:
# CATDESC: MMS/FPI pixel label used in some types of outputs
# FIELDNAM: MMS/FPI pixel label
# FORMAT: A11
# VAR_NOTES: Zenith bin labels
# VAR_TYPE: metadata
#
# Attributes for mms1_des_energy_label_brst:
# CATDESC: MMS/FPI energy-bin label used in some types of outputs
# FIELDNAM: MMS/FPI energy label
# FORMAT: A11
# LABLAXIS: mms1_des_energy_label_brst
# VAR_NOTES: FPI operations nominally bin data from 64 energy filters into 32 pairwise energy bins, indexed 0-31.  Nominally, bins are indexed in increasing energy order.  See FPI docs for details.
# VAR_TYPE: metadata
#
# Attributes for mms1_des_theta_brst:
# CATDESC: MMS FPI/DES burst sky-map zenith angles
# COORDINATE_SYSTEM: DBCS>Despun Body Coordinate System
# DELTA_PLUS_VAR: mms1_des_theta_delta_brst
# DELTA_MINUS_VAR: mms1_des_theta_delta_brst
# FIELDNAM: MMS/FPI theta
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABLAXIS: theta
# REPRESENTATION_1: t
# SCALETYP: linear
# SI_CONVERSION: 0.0174532925>rad
# UNITS: deg
# VALIDMIN: 0.0
# VALIDMAX: 180.0
# VAR_NOTES: Pixel zenith angles; i.e., the polar angle of the instrument's look direction
# VAR_TYPE: support_data
#
# Attributes for mms1_des_theta_delta_brst:
# CATDESC: MMS1 FPI/DES brst survey sky-map zenith angle bin deltas
# COORDINATE_SYSTEM: DBCS>Despun Body Coordinate System
# FIELDNAM: MMS1 FPI/DES delta theta
# FILLVAL: -9.999999848243207e+30
# FORMAT: E10.3
# LABLAXIS: delta theta
# REPRESENTATION_1: t
# SCALETYP: linear
# SI_CONVERSION: 0.0174532925>rad
# UNITS: deg
# VALIDMIN: 0.0
# VALIDMAX: 10.0
# VAR_NOTES: Pixel zenith angle deltas
# VAR_TYPE: support_data
#
# Attributes for mms1_des_energy_brst:
# CATDESC: MMS FPI/DES burst sky-map parity 0/1 energies
# COORDINATE_SYSTEM: DBCS>Despun Body Coordinate System
# DELTA_PLUS_VAR: mms1_des_energy_delta_brst
# DELTA_MINUS_VAR: mms1_des_energy_delta_brst
# DEPEND_0: Epoch
# FIELDNAM: MMS/FPI energy
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABLAXIS: energy
# REPRESENTATION_1: r
# SCALETYP: log
# SI_CONVERSION: 1.6021773E-19>J
# UNITS: eV
# VALIDMIN: 0.0
# VALIDMAX: 30000.0
# VAR_NOTES: Energies (parity 0/1) in the 64-step FPI energy table
# VAR_TYPE: support_data
#
# Attributes for mms1_des_energy_delta_brst:
# CATDESC: MMS1 FPI/DES brst survey sky-map delta energies
# COORDINATE_SYSTEM: DBCS>Despun Body Coordinate System
# DEPEND_0: Epoch
# FIELDNAM: MMS1 FPI/DES delta energy
# FILLVAL: -9.999999848243207e+30
# FORMAT: E12.2
# LABLAXIS: delta energy
# REPRESENTATION_1: r
# SCALETYP: log
# SI_CONVERSION: 1.6021773E-19>J
# UNITS: eV
# VALIDMIN: 0.0
# VALIDMAX: 5000.0
# VAR_NOTES: Note that the deltas are provided to indicate that FPI is reporting the energy bin centers. These do not necessarily reflect the energy bandwidth that is sampled by FPI at a given energy step.
# VAR_TYPE: support_data
#
# Variable Data Sizes:
# Epoch: (4666,)
# Epoch_plus_var: 0.029999999329447746
# Epoch_minus_var: 0.0
# mms1_des_errorflags_brst: (4666,)
# mms1_des_compressionloss_brst: (4666,)
# mms1_des_steptable_parity_brst: (4666,)
# mms1_des_startdelphi_count_brst: (4666,)
# mms1_des_startdelphi_angle_brst: (4666,)
# mms1_des_phi_brst: (4666, 32)
# mms1_des_phi_delta_brst: (32,)
# mms1_des_dist_brst: (4666, 32, 16, 32)
# mms1_des_disterr_brst: (4666, 32, 16, 32)
# mms1_des_avgf1counts_brst: (4666, 32)
# mms1_des_steptimeoffsets_brst: (4666, 32, 16, 32)
# mms1_des_sector_despinp_brst: (4666,)
# mms1_des_sector_label_brst: (1, 32)
# mms1_des_pixel_label_brst: (1, 16)
# mms1_des_energy_label_brst: (1, 32)
# mms1_des_theta_brst: (16,)
# mms1_des_theta_delta_brst: (16,)
# mms1_des_energy_brst: (4666, 32)
# mms1_des_energy_delta_brst: (4666, 32)

# %%
dist_data = cdf_file.varget('mms1_des_dist_brst')
phi_data = cdf_file.varget('mms1_des_phi_brst')
theta_data = cdf_file.varget('mms1_des_theta_brst')
energy_data = cdf_file.varget('mms1_des_energy_brst')
epoch_data = cdf_file.varget('Epoch')

# %%
dist_data.shape, phi_data.shape, theta_data.shape, energy_data.shape, epoch_data.shape
# Out:
# ((4666, 32, 16, 32), (4666, 32), (16,), (4666, 32), (4666,))

# %%
phi_data.shape
# Out:
# (4666, 32)

# %%
pd.DataFrame(energy_data)
# Out:
#         0     1      2      3      4      5          6          7      8   \
# 0     6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 1     6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 2     6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 3     6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 4     6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# ...    ...   ...    ...    ...    ...    ...        ...        ...    ...
# 4661  6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 4662  6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 4663  6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 4664  6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
# 4665  6.52  8.54  11.17  14.63  19.15  25.07  32.810001  42.950001  56.23
#
#              9   ...           22           23           24           25  \
# 0     73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 1     73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 2     73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 3     73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 4     73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# ...         ...  ...          ...          ...          ...          ...
# 4661  73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 4662  73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 4663  73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 4664  73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
# 4665  73.599998  ...  2438.919922  3192.610107  4179.200195  5470.680176
#
#            26       27            28            29            30       31
# 0     7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 1     7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 2     7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 3     7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 4     7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# ...       ...      ...           ...           ...           ...      ...
# 4661  7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 4662  7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 4663  7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 4664  7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
# 4665  7161.25  9374.25  12271.120117  16063.200195  21027.109375  27525.0
#
# [4666 rows x 32 columns]

# %% [markdown]
# Number density: As described earlier.
# Bulk velocity: Weighted by the phase space density and integrated over energy, azimuth, and elevation.
# Pressure tensor: Involves the second moment of the velocity distribution.
# Entropy: Using specific integrals, possibly linked with entropy flux.

# %%
import sys
sys.path.append("C://Users//ryane//Desktop//Aurora_Project//MMS-FPI-Data-Gaps//mmspy")

from moments import Moments

mom = Moments()

# %%
nen =energy_data.shape[1]  # energy_data is in shape (time, energy)

# %%
mom=Moments(nen_corrected=nen) # Initialize the Moments class with the number of energy bins

# %%
# timestep_index = 0
# fg = dist_data[timestep_index, :, :, :]  # Shape (nen, nth, nph) - phase space distribution

# # Set the energy levels for this timestep
# mom.energy_corrected = energy_data[timestep_index, :]  # Assuming shape (32,) for 32 energy bins

# # Loop through the energy levels and compute angle integrals for each one
# for i in range(fg.shape[0]):  # Loop over energy levels
#     fg_energy_level = fg[i, :, :]  # Shape (nth, nph) - single energy level distribution
    
#     # Compute angle integrals using the Moments class
#     theta_deg = theta_data  # Assuming this is 1D (shape (16,))
#     phi_deg = phi_data[timestep_index, :]  # Assuming shape (32,) for this timestep
    
#     # Compute the angle integrals for this energy level
#     integrals = mom.compute_angle_integrals(fg_energy_level, theta_deg, phi_deg)

#     # Store the computed angle integrals in the appropriate variables in the Moments class
#     mom.inttheta0[i] = integrals[0]
#     mom.inttheta1[i] = integrals[1]
#     mom.inttheta2[i] = integrals[2]
#     mom.inttheta3[i] = integrals[3]
#     mom.inttheta4[i] = integrals[4]
#     mom.inttheta5[i] = integrals[5]
#     mom.inttheta6[i] = integrals[6]
#     mom.inttheta7[i] = integrals[7]
#     mom.inttheta8[i] = integrals[8]
#     mom.inttheta9[i] = integrals[9]

# # Now, you can proceed to calculate the energy integrals based on these results
# mom.compute_energy_integrals()

# # After computation, print the moments
# print(f"Density = {mom.density}, vx = {mom.vx}, vy = {mom.vy}, vz = {mom.vz}")
# Out:
# Density = 168241.9498030058, vx = -61157.88147662828, vy = -20453.676123442132, vz = 1443.5222667234552

# %%
# Loop over all timesteps
# Initialize lists to store the moments for each timestep
densities = []
vx_list = []
vy_list = []
vz_list = []

# Loop over all timesteps
for t in range(len(dist_data)):
    # Initialize a new Moments instance for each timestep
    mom = Moments(nen_corrected=32)  # Adjust 'nen_corrected' as per your actual data
    
    fg = dist_data[t, :, :, :]  # Distribution function for this timestep
    mom.energy_corrected = energy_data[t, :]  # Set energy levels
    
    # Loop through the energy levels and compute angle integrals for each one
    for i in range(fg.shape[0]):  # Loop over energy levels
        fg_energy_level = fg[i, :, :]  # Shape (nth, nph) - single energy level distribution
        
        # Compute angle integrals for this energy level
        integrals = mom.compute_angle_integrals(fg_energy_level, theta_data, phi_data[t, :])
        # Check constants compute_angle_integrals
        
        # Store the computed angle integrals
        mom.inttheta0[i] = integrals[0]
        mom.inttheta1[i] = integrals[1]
        mom.inttheta2[i] = integrals[2]
        mom.inttheta3[i] = integrals[3]
        mom.inttheta4[i] = integrals[4]
        mom.inttheta5[i] = integrals[5]
        mom.inttheta6[i] = integrals[6]
        mom.inttheta7[i] = integrals[7]
        mom.inttheta8[i] = integrals[8]
        mom.inttheta9[i] = integrals[9]

    # Calculate energy integrals after computing angle integrals for all energy bins
    mom.compute_energy_integrals()
    # Check constants compute_angle_integrals

    # Store the moments for plotting later
    densities.append(mom.density)
    vx_list.append(mom.vx)
    vy_list.append(mom.vy)
    vz_list.append(mom.vz)

# %%
plt.figure(figsize=(8, 6))
plt.plot(densities, label='Density')
plt.title('Density over Time')
plt.xlabel('Timestep')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# Plot the velocity components over time
plt.figure(figsize=(8, 6))
plt.plot(vx_list, label='vx')
plt.plot(vy_list, label='vy')
plt.plot(vz_list, label='vz')
plt.title('Velocity Components over Time')
plt.xlabel('Timestep')
plt.ylabel('Velocity (km/s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# with cdflib.CDF(fp_mms1_moms) as cdf_file:  # Ensure to use the correct file path for moments data
#     # Get the variable names using cdf_info().rVariables and zVariables
#     cdf_info = cdf_file.cdf_info()
#     variables = cdf_info.rVariables + cdf_info.zVariables
    
#     # Print all the variable names to see if magnetic field components are present
#     print("\nVariables:")
#     for var in variables:
#         print(var)

#     # # Optionally, print the attributes for the variables to check details
#     # print("\nVariable Attributes:")
#     # for var in variables:
#     #     var_attrs = cdf_file.varattsget(var)
#     #     print(f"\nAttributes for {var}:")
#     #     for attr, value in var_attrs.items():
#     #         print(f"{attr}: {value}")
    
    
# Bx = cdf_file.varget('Bx')  # Replace with the correct variable name
# By = cdf_file.varget('By')
# Bz = cdf_file.varget('Bz')

# %% [markdown]
# # Check this

# %%
def calculate_pitch_angle(vx, vy, vz, Bx, By, Bz):
    # Compute the dot product between velocity and magnetic field vectors
    v_dot_B = vx * Bx + vy * By + vz * Bz
    
    # Compute the magnitudes of velocity and magnetic field vectors
    v_magnitude = np.sqrt(vx**2 + vy**2 + vz**2)
    B_magnitude = np.sqrt(Bx**2 + By**2 + Bz**2)
    
    # Compute the cosine of the pitch angle
    cos_alpha = v_dot_B / (v_magnitude * B_magnitude)
    
    # Compute the pitch angle in radians and convert to degrees
    pitch_angle = np.arccos(np.clip(cos_alpha, -1.0, 1.0)) * (180 / np.pi)
    
    return pitch_angle

# Assuming you have Bx, By, Bz from the CDF file for each timestep
# And you have the computed velocity moments vx, vy, vz from the moments integrals

for t in range(len(dist_data)):
    vx, vy, vz = mom.vx, mom.vy, mom.vz  # Velocity moments from the Moments calculation
    Bx, By, Bz = Bx_data[t], By_data[t], Bz_data[t]  # Magnetic field components from the data
    
    # Calculate the pitch angle for this timestep
    pitch_angle = calculate_pitch_angle(vx, vy, vz, Bx, By, Bz)
    
    print(f"Timestep {t}: Pitch Angle = {pitch_angle} degrees")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 22
#      20 for t in range(len(dist_data)):
#      21     vx, vy, vz = mom.vx, mom.vy, mom.vz  # Velocity moments from the Moments calculation
# ---> 22     Bx, By, Bz = Bx_data[t], By_data[t], Bz_data[t]  # Magnetic field components from the data
#      24     # Calculate the pitch angle for this timestep
#      25     pitch_angle = calculate_pitch_angle(vx, vy, vz, Bx, By, Bz)
#
# NameError: name 'Bx_data' is not defined

# %%
# Open the CDF file and extract magnetic field components (Bx, By, Bz)
with cdflib.CDF(fp_mms1_dist) as cdf_file:
    Bx_data = cdf_file.varget('mms1_fgm_b_gse_brst_x')  # Example variable name for Bx
    By_data = cdf_file.varget('mms1_fgm_b_gse_brst_y')  # Example variable name for By
    Bz_data = cdf_file.varget('mms1_fgm_b_gse_brst_z')  # Example variable name for Bz
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Open the CDF file and extract magnetic field components (Bx, By, Bz)
#       2 with cdflib.CDF(fp_mms1_dist) as cdf_file:
# ----> 3     Bx_data = cdf_file.varget('mms1_fgm_b_gse_brst_x')  # Example variable name for Bx
#       4     By_data = cdf_file.varget('mms1_fgm_b_gse_brst_y')  # Example variable name for By
#       5     Bz_data = cdf_file.varget('mms1_fgm_b_gse_brst_z')
#
# File ~\anaconda3\lib\site-packages\cdflib\cdfread.py:434, in CDF.varget(self, variable, epoch, starttime, endtime, startrec, endrec)
#     431 if (starttime is not None or endtime is not None) and (startrec != 0 or endrec is not None):
#     432     raise ValueError("Can't specify both time and record range")
# --> 434 vdr_info = self.vdr_info(variable)
#     435 if vdr_info.max_rec < 0:
#     436     raise ValueError(f"No records found for variable {variable}")
#
# File ~\anaconda3\lib\site-packages\cdflib\cdfread.py:466, in CDF.vdr_info(self, variable)
#     464         num_variables = self._num_rvariable
#     465     if vdr_info is None:
# --> 466         raise ValueError(f"Variable name '{variable}' not found.")
#     467 elif isinstance(variable, int):
#     468     if self._num_zvariable > 0:
#
# ValueError: Variable name 'mms1_fgm_b_gse_brst_x' not found.

# %%
Desktop/Aurora_Project/MMS-FPI-Data-Gaps/data/mms1/fpi/brst/l2/des-moms/2024/01/01/mms1_fpi_brst_l2_des-moms_20240101131913_v3.4.0.cdf
